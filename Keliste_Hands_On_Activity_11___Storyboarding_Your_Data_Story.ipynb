# %% [markdown]
# <a href="https://colab.research.google.com/github/AiconKeliste/CPE031-Visualization-and-Data-Analysis/blob/main/Keliste_Hands_On_Activity_11___Storyboarding_Your_Data_Story.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Hands-On Activity 11 | Storyboarding Your Data Story**
#
#
#
#
#
# ---

# %% [markdown]
# Name : Aicon H. Keliste <br>
# Course Code and Title : CPE 031 Visualization and Data Analysis<br>
# Date Submitted : 11-6-25<br>
# Instructor : Maam Sayo
#
#
# ---

# %% [markdown]
# **1. Objectives:**
#
# This activity aims to help students demonstrate the ability to plan and visualize a simple data story using a storyboard approach, combining storytelling elements with visual thinking before coding full visualizations.

# %% [markdown]
# **2. Intended Learning Outcomes (ILOs):**
#
# By the end of this activity, students should be able to:
#
# 1. Analyze a dataset and identify the key message or insight.
#
# 2. Organize a logical flow for storytelling using a storyboard structure.
#
# 3. Create a simple storyboard visualization in Python.

# %% [markdown]
# **3. Discussions:**
#
# Storyboarding helps plan how your data story will unfold just like scenes in a movie.
# It helps you decide what charts, annotations, or visuals are needed to communicate your message effectively.
#
# A typical storyboard has:
#
# Frame 1: Title or question (What are we exploring?)
#
# Frame 2: Key data visualization or comparison
#
# Frame 3: Main insight or conclusion
#
# In Python, you can simulate a storyboard using multiple subplots each representing a scene or frame in your story.

# %% [markdown]
# **4. Procedures:**

# %% [markdown]
# Storyboard Example – “Sales Growth Over Time”

# %%
# Import libraries
import matplotlib.pyplot as plt

# Sample data
years = [2020, 2021, 2022, 2023, 2024]
sales = [100, 150, 200, 300, 450]

# Create storyboard using subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Frame 1: Title / Introduction
axes[0].text(0.5, 0.5, "Our Sales Journey\n(2020–2024)", ha='center', va='center', fontsize=14)
axes[0].axis("off")

# Frame 2: Key Data Visualization
axes[1].plot(years, sales, marker='o', color='steelblue')
axes[1].set_title("Sales Over Time")
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Sales (in units)")

# Frame 3: Insight / Message
axes[2].text(0.5, 0.5, "Insight:\nSales grew steadily,\nwith a big jump after 2022!",
             ha='center', va='center', fontsize=12, color='darkgreen')
axes[2].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
#
# **5. Supplementary Activity:**

# %% [markdown]
# 1. Choose a small dataset (e.g., from Kaggle or manually created).
# Then, create a 3-frame storyboard in Python showing:
#
# Frame 1: Title or question
#
# Frame 2: One simple chart (bar or line)
#
# Frame 3: Main message or conclusion
#
# 2. Use matplotlib and label each part clearly.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df  = pd.read_csv("/content/drive/MyDrive/VDA/HOA 11/ElectricCarData_Clean.csv")
df
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create storyboard using subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Frame 1: Title / Introduction
axes[0].text(0.5, 0.5, "Electric Car Wheel Drive", ha='center', va='center', fontsize=16)
axes[0].axis("off")

# Frame 2: Simple Chart (Bar Chart of average range by PowerTrain)
avg_range_by_powertrain = df.groupby('PowerTrain')['Range_Km'].mean().sort_values(ascending=False)
powertrains = avg_range_by_powertrain.index
avg_ranges = avg_range_by_powertrain.values

axes[1].bar(powertrains, avg_ranges, color=['blue', 'green', 'red'])
axes[1].set_title("Average Range by PowerTrain")
axes[1].set_xlabel("PowerTrain")
axes[1].set_ylabel("Average Range (Km)")

# Frame 3: Insight / Message
axes[2].text(0.5, 0.5, "Insight:\nAWD cars generally have a higher average range\nin this dataset.",
             ha='center', va='center', fontsize=14, color='darkblue')
axes[2].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# **6. Conclusion/Learnings/Analysis:**

# %% [markdown]
# Through this activity, I learned how to effectively plan and visualize a simple data story using a storyboard approach. By creating a 3-frame storyboard in Python, I was able to analyze the electric car dataset, identify a key insight about the average range of different powertrains (AWD, RWD, FWD), and communicate this finding clearly through a bar chart and a concluding message. This exercise reinforced the importance of structuring a data narrative and using visual elements to convey information concisely.
